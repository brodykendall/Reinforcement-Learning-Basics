# %% [markdown]
# In this problem, you will fill in several blank parts of the code to make DeepQLearning work. You will then answer a few brief questions about the learning progress of a Q-learning algorithm.
#
# Note that we are applying deep-q-learning to cartpole, which has a continuous state space! This is not possible with the tabular version of q-learning from the last problem, because you can not trivially map continuous values into a lookup table.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import random
import gym

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

NStates = 4
NActions = 2

# %%
# Define our neural net we will use to estimate the Q-function
class QFunctionNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(QFunctionNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %% [markdown]
# Next we need to add a replay buffer. This buffer should hold past data collected by the agent. It should have a max memory size of 10,000. The buffer should be circular, in the sense that the oldest data gets removed once it reaches the overflow limit.
#
# You need to implement add_to_buffer, which allows you to add data to the buffer. You also need to implement sample_buffer, which pulls at random (with replacement) 32 datapoints from the buffer and returns them.

# %%
class ReplayBuffer:
    def __init__(self, mem_size=10000):
        self.mem_count = 0
        self.mem_size = mem_size
        self.states = np.zeros((mem_size, 4), dtype=np.float32)
        self.actions = np.zeros(mem_size, dtype=np.int64)
        self.rewards = np.zeros(mem_size, dtype=np.float32)
        self.next_states = np.zeros((mem_size, 4), dtype=np.float32)
        self.terminated = np.zeros(mem_size, dtype=bool)

    def add_to_buffer(self, state, action, reward, next_state, terminated):
        # add state, action, reward, next_state, terminated to the buffer. Note you only have one copy of each. For example, state is just a (4,) dimensional array.
        self.states[self.mem_count % self.mem_size, range(4)] = state
        self.actions[self.mem_count % self.mem_size] = action
        self.rewards[self.mem_count % self.mem_size] = reward
        self.next_states[self.mem_count % self.mem_size, range(4)] = next_state
        self.terminated[self.mem_count % self.mem_size] = terminated
        self.mem_count += 1
        return True

    def sample_buffer(self, batch_size=32):
        MEM_MAX = np.min([self.mem_count, self.mem_size])
        batch_indices = np.random.choice(MEM_MAX, batch_size, replace = True)
        states_mb = self.states[batch_indices,]
        actions_mb = self.actions[batch_indices]
        rewards_mb = self.rewards[batch_indices]
        next_states_mb = self.next_states[batch_indices,]
        terminated_mb = self.terminated[batch_indices]
        return states_mb, actions_mb, rewards_mb, next_states_mb, terminated_mb

# %% [markdown]
# RL agents are typically writen as classes with three essential methods. First, an initialization. Second, train which takes a batch of states, actions, rewards, next states, and termination signals and trains the neural network loss. Finally, a get_action function which takes the current observation and returns the action the agent should take.

# %%
class QLearningAgent:
    def __init__(self, env, epsilon_greedy_threshold=0.50, epsilon_decay=0.995):
        self.env = env
        #self.replayBuffer = ReplayBuffer()
        self.q_func = QFunctionNet(input_size=NStates, num_classes=NActions, hidden_size=128).to(device)

        self.criterion = nn.MSELoss()
#         self.criterion = nn.SmoothL1Loss()
#         self.optimizer = torch.optim.RMSprop(self.q_func.parameters())
        self.optimizer = torch.optim.Adam(self.q_func.parameters(), lr=0.0001)

        self.epsilon_greedy_threshold = epsilon_greedy_threshold
        self.epsilon_decay = epsilon_decay

        self.gamma = 0.95

        self.total_training_steps = 0

    def train(self, states, acts, rews, next_states, terminated):

        #Torch and numpy don't like each other. So you have to spend a lot of time doing these kinds of conversions from numpy data that is stored in the buffer into Torch data. This is just making sure Torch can process the data, by converting it into a tensor.
        states_torch = torch.from_numpy(states).float()
        acts_torch = torch.from_numpy(acts)
        next_states_torch = torch.from_numpy(next_states).float()
        rews_torch = torch.from_numpy(rews).float()
        terminated_torch = torch.from_numpy(terminated).float()

        # you need this to grab the q-values at the current state.
        batch_indices = np.arange(len(states), dtype=np.int64)


        q_values = self.q_func(states_torch)# use your neural net
        next_q_values = self.q_func(next_states_torch)# use your neural net again

        # This is the Q-values at the actions that were actually taken. So you need to fill in the second index to account for the actions that were taken.
        predicted_q_values_at_actions_taken = predicted_value_of_now = q_values[batch_indices, acts_torch]

        # remember how Q-learning assumes you take the action leading to the maximal q-value at the next step? It's the argmax part of the td-target. This is the code version of that situation. You want to look at next_q_values and take the max along the action dimension, which will give you the estimated q-value at the best possible action.

        # Use the torch.max function. 
        predicted_q_values_at_best_future_actions = torch.max(next_q_values, dim=1)[0]####

        # Fill in the missing term in the q-target.
        q_target = rews_torch + self.gamma * predicted_q_values_at_best_future_actions * (1-terminated_torch)


        loss = self.criterion(q_target, predicted_q_values_at_actions_taken)

        self.optimizer.zero_grad()
        loss.backward()

        self.optimizer.step()

        if self.total_training_steps % 1 == 0:
            # There are a few ways to handle decreasing the epsilon greedy threshold.
            # They tend to involve either multiplication or subtraction.
            # You want the threshold to decay towards 0 over the course of training.
            self.epsilon_greedy_threshold *= self.epsilon_decay

        self.total_training_steps += 1

    def get_action(self, obs, evaluate=False):
        obs_correct_format = torch.from_numpy(np.expand_dims(obs, 0))
        action_values = self.q_func(obs_correct_format)
        action_values = action_values.cpu().detach().numpy()[0]

        print(f"action values: {action_values}")

        # during evaluation, we do not want epsilon greedy sampling.
        if evaluate is False:
            p = random.uniform(0, 1)
            if p > self.epsilon_greedy_threshold:
                action = np.argmax(action_values) 
                print(f"selected action: {action}")
            else:
                action = self.env.action_space.sample()
            return action
        else:
            # we are not evaluating, so we always want to return the best action with no exploration.
            action = np.argmax(action_values)
            return action

# %% [markdown]
# Fancy plotting utility shown in class. Can produce a plot in real time, making it look kind of like a video. It's fun to use sometimes, although not really practical in real life.

# %%
def plot_fancy(steps_survived_history):
    plt.figure(2)
    plt.clf()
    #durations_t = torch.FloatTensor(episode_durations)
    steps_survived_history_torch = torch.FloatTensor(steps_survived_history)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(np.array(steps_survived_history))
    # take 100 episode averages and plot them too
    if len(steps_survived_history) >= 20:
        means = steps_survived_history_torch.unfold(0, 20, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(19), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
env = gym.make('CartPole-v1')
env.action_space.sample()
# Out:
# 1

# %%
action_space = [0,1]
random.sample(action_space, k=1)[0]
# Out:
# 0

# %% [markdown]
# Now all we need is the main loop.

# %%
def main():

    env = gym.make('CartPole-v1')
    env.action_space.seed(42)
    env.observation_space.seed(42)
    np.random.seed(42)
    random.seed(42)

    obs, info = env.reset()

    replay_buffer = ReplayBuffer()
    q_learning_agent = QLearningAgent(env = env)

    # total training episodes
    epochs = 2000

    # Store the history of how long we survive.
    steps_survived_history = []
    x_labs = []

    for ep in range(epochs):
        obs, info = env.reset()
        terminated = False

        steps_survived = 0

        while not terminated:

            action = q_learning_agent.get_action(obs=obs)

            next_obs, reward, terminated, truncated, info = env.step(action)

            replay_buffer.add_to_buffer(state=obs, action=action,
                                        reward=reward, next_state=next_obs,
                                        terminated=terminated)

            obs = next_obs

            steps_survived += 1

            if steps_survived > 450:
                break

        if(len(replay_buffer.states)) > 100:
            # train 20 times per episode collected.
            for i in range(0, 50):
                states_mb, acts_mb, rews_mb, next_states_mb, terminated = replay_buffer.sample_buffer(batch_size=32)
                q_learning_agent.train(states_mb, acts_mb, rews_mb, next_states_mb, terminated)

        if ep % 7 == 0 and ep > 0:

            steps_survived = 0
            obs, info = env.reset()
            terminated = False
            
            # We do an evaluation loop without exploration.
            while not terminated:
                steps_survived += 1
                action = q_learning_agent.get_action(obs=obs, evaluate=True)

                next_obs, reward, terminated, truncated, info = env.step(action)

                obs = next_obs

                if steps_survived > 450:
                    break

            steps_survived_history.append(steps_survived)
#             print(steps_survived)

            #uncomment the line below for fancy plotting.
            # plot_fancy(steps_survived_history)
            x_labs.append(ep)

    plt.plot(x_labs, steps_survived_history, label='Steps Survived')
    plt.legend()
    plt.show()
    print(np.mean(steps_survived_history[-100:-1]))

# %%
if __name__ == "__main__":
    main()
# Out:
# action values: [ 0.04499604 -0.04223739]
# selected action: 0
# action values: [0.07835595 0.00536241]
# action values: [0.11768278 0.04848418]
# action values: [0.07801969 0.00709786]
# action values: [ 0.04366037 -0.03662141]
# selected action: 0
# action values: [0.08174714 0.01110867]
# selected action: 0
# action values: [0.12365519 0.05478377]
# selected action: 0
# action values: [0.16957885 0.10199633]
# action values: [0.2116831  0.14385799]
# action values: [0.2484636  0.18798916]
# action values: [0.2190494  0.14940597]
# action values: [0.26347783 0.19477305]
# selected action: 0
# action values: [0.07049581 0.02529136]
# action values: [0.0748513  0.00111941]
# action values: [0.07159441 0.02384013]
# selected action: 0
# action values: [0.08795772 0.06548508]
# selected action: 0
# action values: [0.11360352 0.10378602]
# action values: [0.1464149  0.14682981]
# selected action: 1
# action values: [0.10454386 0.09841219]
# selected action: 0
# action values: [0.13982198 0.14286149]
# action values: [0.09896974 0.0944542 ]
# selected action: 0
# action values: [0.1366171  0.13944364]
# selected action: 1
# action values: [0.09545519 0.092025  ]
# action values: [0.06328867 0.05510899]
# action values: [0.05148525 0.01950334]
# selected action: 0
# action values: [0.06661031 0.057949  ]
# action values: [0.051138   0.02107323]
# action values: [ 0.05580235 -0.00657654]
# action values: [ 0.0702202  -0.01291917]
# selected action: 0
# action values: [ 0.06031156 -0.00317424]
# selected action: 0
# action values: [0.05733633 0.0267562 ]
# selected action: 0
# action values: [0.08149806 0.06925293]
# selected action: 0
# action values: [0.11352836 0.10707609]
# selected action: 0
# action values: [0.1555441  0.15030631]
# selected action: 0
# action values: [0.19228935 0.18993938]
# action values: [0.15491891 0.15063736]
# selected action: 0
# action values: [0.1985663  0.19216786]
# selected action: 0
# action values: [0.23898157 0.24092594]
# selected action: 1
# action values: [0.20920153 0.19987261]
# selected action: 0
# action values: [0.25463933 0.24603221]
# selected action: 0
# action values: [0.08766729 0.07105185]
# selected action: 0
# action values: [0.10945379 0.10142276]
# action values: [0.14219373 0.13157192]
# action values: [0.10503636 0.10144316]
# action values: [0.13872263 0.13108532]
# action values: [0.10261583 0.1018672 ]
# action values: [0.1371862 0.131519 ]
# action values: [0.1788202  0.16925663]
# action values: [0.13469484 0.13215348]
# selected action: 0
# action values: [0.17971286 0.17039785]
# selected action: 0
# action values: [0.2232375 0.206794 ]
# selected action: 0
# action values: [0.25758722 0.2522801 ]
# action values: [0.22848031 0.21126834]
# action values: [0.19090346 0.18042181]
# selected action: 0
# action values: [0.11181142 0.0968725 ]
# selected action: 0
# action values: [0.13117892 0.12233612]
# selected action: 0
# action values: [0.15755981 0.15138906]
# action values: [0.19123101 0.19133282]
# selected action: 1
# action values: [0.1529434  0.14798865]
# action values: [0.12261751 0.12002431]
# selected action: 0
# action values: [0.15270367 0.1478863 ]
# selected action: 0
# action values: [0.19048624 0.18938416]
# selected action: 0
# action values: [0.22268175 0.22785968]
# selected action: 1
# action values: [0.1910348  0.18799302]
# selected action: 0
# action values: [0.22770973 0.2303116 ]
# selected action: 1
# action values: [0.19502497 0.1903616 ]
# selected action: 0
# action values: [0.237628   0.23595518]
# action values: [0.20390788 0.19769391]
# action values: [0.25347224 0.24486846]
# selected action: 0
# action values: [0.13653821 0.13703507]
# selected action: 1
# action values: [0.13742226 0.1416131 ]
# selected action: 1
# action values: [0.15115872 0.14980993]
# selected action: 0
# action values: [0.14134698 0.14259087]
# selected action: 1
# action values: [0.15534002 0.15024248]
# selected action: 0
# action values: [0.14513025 0.14382544]
# selected action: 0
# action values: [0.14530586 0.13913989]
# selected action: 0
# action values: [0.16966578 0.16729909]
# selected action: 0
# action values: [0.19899869 0.2009278 ]
# selected action: 1
# action values: [0.16356874 0.16543536]
# selected action: 1
# action values: [0.1376962  0.13481292]
# selected action: 0
# action values: [0.16180773 0.16383314]
# selected action: 1
# action values: [0.13630643 0.13387671]
# selected action: 0
# action values: [0.16007024 0.16255522]
# selected action: 1
# action values: [0.13514483 0.13305123]
# selected action: 0
# action values: [0.15855098 0.1614492 ]
# selected action: 1
# action values: [0.13417625 0.1323255 ]
# selected action: 0
# action values: [0.15729105 0.16046895]
# selected action: 1
# action values: [0.13337079 0.13169108]
# selected action: 0
# action values: [0.15626162 0.15960866]
# action values: [0.18322848 0.19026706]
# action values: [0.21556829 0.23073715]
# action values: [0.2440963 0.2663166]
# selected action: 1
# action values: [0.21165879 0.22684318]
# selected action: 1
# action values: [0.17526256 0.18395787]
# selected action: 1
# action values: [0.14398892 0.15636313]
# action values: [0.12080745 0.13069126]
# selected action: 1
# action values: [0.12319212 0.13413829]
# selected action: 1
# action values: [0.13514094 0.14772794]
# selected action: 1
# action values: [0.14575161 0.16599494]
# selected action: 1
# action values: [0.1740106  0.19564879]
# selected action: 1
# action values: [0.20934255 0.22110628]
# action values: [0.2457188 0.2510839]
# selected action: 1
# action values: [0.2901067  0.27885818]
# selected action: 0
# action values: [0.2576378  0.24541438]
# selected action: 0
# action values: [0.22952715 0.21361187]
# selected action: 0
# action values: [0.21445288 0.18780407]
# selected action: 0
# action values: [0.20294797 0.16980007]
# action values: [0.19485952 0.15243955]
# selected action: 0
# action values: [0.17970668 0.14147475]
# selected action: 0
# action values: [0.17346278 0.13188979]
# selected action: 0
# action values: [0.18306586 0.15203643]
# selected action: 0
# action values: [0.19500434 0.18174529]
# selected action: 0
# action values: [0.20092142 0.21603554]
# selected action: 1
# action values: [0.17539081 0.16653492]
# action values: [0.15377167 0.13216808]
# selected action: 0
# action values: [0.16370347 0.15578888]
# selected action: 0
# action values: [0.17326994 0.18226254]
# selected action: 1
# action values: [0.15193605 0.14264461]
# selected action: 0
# action values: [0.15875188 0.16466144]
# selected action: 1
# action values: [0.1426889  0.12904581]
# action values: [0.16546735 0.12276113]
# selected action: 0
# action values: [0.14074449 0.11823088]
# selected action: 0
# action values: [0.14363424 0.13953844]
# selected action: 0
# action values: [0.14158209 0.16620687]
# selected action: 1
# action values: [0.13587019 0.12975764]
# action values: [0.13445732 0.15511078]
# selected action: 1
# action values: [0.13190214 0.11925206]
# action values: [0.17915922 0.11308838]
# selected action: 0
# action values: [0.17217255 0.15392262]
# selected action: 0
# action values: [0.18930227 0.1780996 ]
# selected action: 0
# action values: [0.21308607 0.20565994]
# selected action: 0
# action values: [0.24370182 0.24317172]
# action values: [0.2688654  0.28038892]
# selected action: 1
# action values: [0.23760584 0.2389277 ]
# selected action: 1
# action values: [0.2004132  0.19731522]
# action values: [0.1726701  0.17201503]
# selected action: 0
# action values: [0.20175157 0.19846506]
# action values: [0.17311269 0.17422557]
# selected action: 1
# action values: [0.15107672 0.15527856]
# selected action: 1
# action values: [0.1561046  0.15654244]
# action values: [0.15365541 0.15776056]
# selected action: 1
# action values: [0.15730304 0.15593494]
# selected action: 0
# action values: [0.15542617 0.16005902]
# selected action: 1
# action values: [0.15801138 0.15520358]
# selected action: 0
# action values: [0.15711266 0.16400361]
# selected action: 1
# action values: [0.15848875 0.15540287]
# selected action: 0
# action values: [0.16040912 0.16874999]
# selected action: 1
# action values: [0.15731782 0.15490423]
# selected action: 0
# action values: [0.1642389  0.17336552]
# selected action: 1
# action values: [0.1556193  0.15442912]
# selected action: 0
# action values: [0.17081946 0.17633717]
# selected action: 1
# action values: [0.15489957 0.15371948]
# selected action: 0
# action values: [0.18083368 0.17948504]
# selected action: 0
# action values: [0.22700614 0.21390986]
# selected action: 0
# action values: [0.2813238  0.24672443]
# action values: [0.33882055 0.27744335]
# selected action: 0
# action values: [0.38282442 0.32662374]
# selected action: 0
# action values: [0.18755208 0.18640241]
# selected action: 0
# action values: [0.20841458 0.21268632]
# selected action: 1
# action values: [0.1868877  0.18635845]
# selected action: 0
# action values: [0.20854327 0.21346861]
# action values: [0.18634017 0.18657953]
# selected action: 1
# action values: [0.19369754 0.19805332]
# selected action: 1
# action values: [0.21134332 0.21290745]
# selected action: 1
# action values: [0.23255408 0.23892693]
# selected action: 1
# action values: [0.26902005 0.27751777]
# action values: [0.24136183 0.23703907]
# selected action: 0
# action values: [0.22704339 0.21163195]
# selected action: 0
# action values: [0.2116153  0.20134206]
# selected action: 0
# action values: [0.21019098 0.19146788]
# selected action: 0
# action values: [0.2278434  0.21510394]
# selected action: 0
# action values: [0.2533265  0.24690916]
# selected action: 0
# action values: [0.28108934 0.28431958]
# selected action: 1
# action values: [0.24528408 0.24354234]
# selected action: 0
# action values: [0.2756039  0.28130773]
# selected action: 1
# action values: [0.2381027  0.24142025]
# selected action: 1
# action values: [0.20619032 0.21305567]
# action values: [0.18463463 0.18673873]
# selected action: 1
# action values: [0.19277075 0.20038971]
# selected action: 1
# action values: [0.21181795 0.21469018]
# selected action: 1
# action values: [0.23398137 0.24334888]
# selected action: 1
# action values: [0.27219737 0.28162616]
# selected action: 1
# action values: [0.31338114 0.32316393]
# selected action: 1
# action values: [0.3637673 0.3602895]
# action values: [0.42455086 0.3968044 ]
# selected action: 0
# action values: [0.38296437 0.3537299 ]
# selected action: 0
# action values: [0.3467412  0.31626636]
# selected action: 0
# action values: [0.32562897 0.28609335]
# selected action: 0
# action values: [0.22366413 0.20494024]
# selected action: 0
# action values: [0.22628883 0.21599454]
# selected action: 0
# action values: [0.24123809 0.23716564]
# selected action: 0
# action values: [0.26756072 0.267466  ]
# selected action: 0
# action values: [0.29277372 0.30256012]
# selected action: 1
# action values: [0.2623316  0.26310495]
# selected action: 1
# action values: [0.23034686 0.23011312]
# selected action: 0
# action values: [0.26246187 0.26192135]
# selected action: 0
# action values: [0.29361415 0.30038646]
# selected action: 1
# action values: [0.26333916 0.26087016]
# action values: [0.22663441 0.22911406]
# selected action: 1
# action values: [0.201725   0.21437325]
# selected action: 1
# action values: [0.18894288 0.2063449 ]
# selected action: 1
# action values: [0.20019734 0.21005255]
# selected action: 1
# action values: [0.21168596 0.22836934]
# selected action: 1
# action values: [0.23732713 0.25816458]
# selected action: 1
# action values: [0.25728422 0.29787177]
# selected action: 1
# action values: [0.29590577 0.33723706]
# selected action: 1
# action values: [0.33953384 0.38287634]
# selected action: 1
# action values: [0.3903497 0.4271577]
# action values: [0.4428505 0.4740973]
# selected action: 1
# action values: [0.4992111 0.5272652]
# selected action: 1
# action values: [0.5624004 0.5818448]
# selected action: 1
# action values: [0.63028955 0.63307655]
# selected action: 1
# action values: [0.70379394 0.6834331 ]
# selected action: 0
# action values: [0.23428625 0.22590482]
# action values: [0.24279472 0.24031039]
# action values: [0.26238367 0.26050407]
# action values: [0.29525405 0.29161513]
# action values: [0.32643124 0.32487196]
# action values: [0.3559641  0.37003136]
# action values: [0.33110598 0.32638723]
# action values: [0.36637545 0.37393022]
# action values: [0.33748162 0.33178806]
# action values: [0.23824486 0.23257726]
# selected action: 0
# action values: [0.2514615 0.2508254]
# selected action: 0
# action values: [0.27638763 0.2728752 ]
# selected action: 0
# action values: [0.30732933 0.30600485]
# selected action: 0
# action values: [0.33822343 0.335711  ]
# selected action: 0
# action values: [0.36340684 0.378602  ]
# selected action: 1
# action values: [0.34056193 0.33579707]
# selected action: 0
# action values: [0.3728043  0.38155842]
# selected action: 1
# action values: [0.34736887 0.33994398]
# selected action: 0
# action values: [0.38652784 0.38565195]
# selected action: 0
# action values: [0.26006794 0.24545825]
# selected action: 0
# action values: [0.26856554 0.2601589 ]
# selected action: 0
# action values: [0.28856915 0.27979866]
# selected action: 0
# action values: [0.3199336 0.3084625]
# selected action: 0
# action values: [0.3496636  0.34075433]
# selected action: 0
# action values: [0.37988263 0.3861409 ]
# selected action: 1
# action values: [0.35332492 0.34179443]
# selected action: 0
# action values: [0.38885975 0.38894492]
# selected action: 1
# action values: [0.3595719 0.3465986]
# selected action: 0
# action values: [0.40411842 0.39215115]
# selected action: 0
# action values: [0.2782584  0.27529162]
# selected action: 0
# action values: [0.29185435 0.29316977]
# selected action: 1
# action values: [0.2776593  0.27484068]
# selected action: 0
# action values: [0.29302898 0.29432312]
# selected action: 1
# action values: [0.27552494 0.2744423 ]
# selected action: 0
# action values: [0.29425627 0.2957686 ]
# selected action: 1
# action values: [0.27313563 0.2745149 ]
# selected action: 1
# action values: [0.28623745 0.28905147]
# selected action: 1
# action values: [0.30104902 0.30657458]
# selected action: 1
# action values: [0.32927993 0.33579266]
# selected action: 1
# action values: [0.3630404  0.37917274]
# selected action: 1
# action values: [0.40218765 0.43382385]
# selected action: 1
# action values: [0.45667258 0.4826908 ]
# selected action: 1
# action values: [0.51468486 0.53415346]
# selected action: 1
# action values: [0.5714506 0.5860798]
# selected action: 1
# action values: [0.6417378 0.6420346]
# selected action: 1
# action values: [0.71494365 0.69969594]
# selected action: 0
# action values: [0.67378366 0.635933  ]
# selected action: 0
# action values: [0.30813223 0.29401365]
# selected action: 0
# action values: [0.31193066 0.3040061 ]
# selected action: 0
# action values: [0.32342607 0.32162738]
# selected action: 0
# action values: [0.34577852 0.3497071 ]
# selected action: 1
# action values: [0.31749094 0.31777996]
# selected action: 1
# action values: [0.3013841  0.30006394]
# selected action: 0
# action values: [0.31551003 0.31606102]
# selected action: 1
# action values: [0.29899925 0.29923186]
# selected action: 1
# action values: [0.29454708 0.29084522]
# selected action: 0
# action values: [0.2999971  0.29971302]
# selected action: 0
# action values: [0.3159871 0.3152591]
# selected action: 0
# action values: [0.34491605 0.34599307]
# selected action: 1
# action values: [0.31408226 0.31359327]
# selected action: 0
# action values: [0.34688807 0.34540287]
# selected action: 0
# action values: [0.37575984 0.37980312]
# selected action: 1
# action values: [0.3489023  0.34541306]
# selected action: 0
# action values: [0.3824497 0.383332 ]
# selected action: 1
# action values: [0.35528988 0.34950438]
# selected action: 0
# action values: [0.394149   0.38954955]
# action values: [0.3246792  0.31119347]
# selected action: 0
# action values: [0.33232898 0.32471043]
# selected action: 0
# action values: [0.34702206 0.34010863]
# selected action: 0
# action values: [0.3708934  0.36788464]
# selected action: 0
# action values: [0.39340958 0.39891422]
# selected action: 1
# action values: [0.36585224 0.3640048 ]
# selected action: 0
# action values: [0.3923157  0.39658493]
# selected action: 1
# action values: [0.36603612 0.36180687]
# selected action: 0
# action values: [0.3954396 0.3964644]
# selected action: 1
# action values: [0.36690453 0.3625663 ]
# selected action: 0
# action values: [0.40228483 0.40172333]
# selected action: 0
# action values: [0.4436452  0.44730067]
# selected action: 1
# action values: [0.34411302 0.33921105]
# selected action: 0
# action values: [0.3457761 0.3477729]
# selected action: 1
# action values: [0.3431385 0.3387959]
# selected action: 0
# action values: [0.34529266 0.34766948]
# selected action: 1
# action values: [0.34215885 0.33840615]
# selected action: 0
# action values: [0.34496912 0.34766424]
# selected action: 1
# action values: [0.34115532 0.33806923]
# selected action: 0
# action values: [0.34479886 0.3477679 ]
# selected action: 1
# action values: [0.34008443 0.3377281 ]
# action values: [0.3447792 0.3479935]
# selected action: 1
# action values: [0.33914727 0.3372453 ]
# selected action: 0
# action values: [0.3449112  0.34835714]
# selected action: 1
# action values: [0.33830136 0.33686543]
# selected action: 0
# action values: [0.34503886 0.34896553]
# selected action: 1
# action values: [0.33714032 0.33639908]
# selected action: 0
# action values: [0.34510887 0.3498752 ]
# action values: [0.3635147 0.3627854]
# selected action: 0
# action values: [0.39315444 0.39020884]
# selected action: 0
# action values: [0.42061958 0.41699988]
# selected action: 0
# action values: [0.4473055  0.45906925]
# selected action: 1
# action values: [0.423269  0.4176345]
# selected action: 0
# action values: [0.45666638 0.4617939 ]
# selected action: 1
# action values: [0.43291718 0.42147928]
# selected action: 0
# action values: [0.35552728 0.35515493]
# selected action: 0
# action values: [0.35891527 0.35999197]
# selected action: 1
# action values: [0.35350963 0.35304204]
# selected action: 0
# action values: [0.3596232  0.36098683]
# selected action: 1
# action values: [0.3517363  0.35222217]
# selected action: 1
# action values: [0.37231296 0.37449712]
# selected action: 1
# action values: [0.3953999 0.4019333]
# selected action: 1
# action values: [0.42460236 0.4390733 ]
# selected action: 1
# action values: [0.46048766 0.48701268]
# selected action: 1
# action values: [0.51068103 0.53542536]
# selected action: 1
# action values: [0.5655327  0.58953094]
# selected action: 1
# action values: [0.6247068  0.64314973]
# selected action: 1
# action values: [0.6846699 0.6964309]
# selected action: 1
# action values: [0.75603896 0.75498116]
# selected action: 0
# action values: [0.7088571 0.6909419]
# selected action: 0
# action values: [0.4016592 0.3778591]
# action values: [0.3937575  0.38087332]
# action values: [0.4019261  0.39292192]
# action values: [0.41994023 0.4146178 ]
# action values: [0.4363148  0.43693793]
# action values: [0.41266385 0.41043746]
# action values: [0.43437764 0.4341789 ]
# action values: [0.45538425 0.47525808]
# action values: [0.43266845 0.43238643]
# action values: [0.45863023 0.47700962]
# action values: [0.43563235 0.4351902 ]
# action values: [0.47155157 0.47991252]
# action values: [0.39601105 0.37713742]
# selected action: 0
# action values: [0.39248523 0.3826214 ]
# selected action: 0
# action values: [0.401759   0.39414987]
# selected action: 0
# action values: [0.42156428 0.41701785]
# selected action: 0
# action values: [0.44009233 0.44115525]
# selected action: 1
# action values: [0.4159199 0.4135338]
# selected action: 0
# action values: [0.4394323  0.43892798]
# selected action: 0
# action values: [0.46214688 0.48157436]
# selected action: 1
# action values: [0.4389588  0.43804854]
# selected action: 0
# action values: [0.46969676 0.4840829 ]
# selected action: 1
# action values: [0.44551113 0.44241017]
# selected action: 0
# action values: [0.40067688 0.40206632]
# selected action: 1
# action values: [0.42098698 0.42876327]
# selected action: 1
# action values: [0.44924518 0.454495  ]
# selected action: 1
# action values: [0.4804285 0.4933956]
# selected action: 1
# action values: [0.5254382 0.5392592]
# selected action: 1
# action values: [0.57391506 0.58778256]
# selected action: 1
# action values: [0.6297091  0.63694096]
# selected action: 1
# action values: [0.6920357 0.6858608]
# selected action: 0
# action values: [0.64831364 0.6317764 ]
# selected action: 0
# action values: [0.60876477 0.58563995]
# selected action: 0
# action values: [0.5780264 0.5458484]
# selected action: 0
# action values: [0.42713886 0.42021537]
# selected action: 0
# action values: [0.4308517  0.42815828]
# selected action: 0
# action values: [0.43684125 0.43826064]
# selected action: 1
# action values: [0.42738962 0.426798  ]
# selected action: 0
# action values: [0.43444765 0.43644226]
# selected action: 1
# action values: [0.4244231  0.42596182]
# selected action: 1
# action values: [0.4189839  0.41809633]
# selected action: 0
# action values: [0.42476532 0.42626002]
# selected action: 1
# action values: [0.41682756 0.41679814]
# selected action: 0
# action values: [0.4244591 0.4265612]
# selected action: 1
# action values: [0.41420022 0.41641986]
# selected action: 1
# action values: [0.43253276 0.43446124]
# selected action: 1
# action values: [0.4502546  0.45496398]
# selected action: 1
# action values: [0.47839475 0.4849679 ]
# selected action: 1
# action values: [0.5080699 0.5242106]
# selected action: 1
# action values: [0.5516016  0.56698763]
# selected action: 1
# action values: [0.6030042 0.6147995]
# selected action: 1
# action values: [0.6572288 0.6606988]
# selected action: 1
# action values: [0.708725   0.70601046]
# selected action: 0
# action values: [0.6711346 0.6524427]
# selected action: 0
# action values: [0.6315689  0.60651493]
# selected action: 0
# action values: [0.6008587  0.56843454]
# selected action: 0
# action values: [0.5777421 0.5346129]
# selected action: 0
# action values: [0.45606607 0.4404968 ]
# selected action: 0
# action values: [0.45852506 0.4491986 ]
# selected action: 0
# action values: [0.46535894 0.45981473]
# selected action: 0
# action values: [0.48216176 0.4821347 ]
# action values: [0.50021154 0.5078838 ]
# selected action: 1
# action values: [0.47561577 0.47685397]
# selected action: 1
# action values: [0.4535117  0.45297217]
# selected action: 0
# action values: [0.47507438 0.4744503 ]
# selected action: 0
# action values: [0.49882892 0.5034838 ]
# selected action: 1
# action values: [0.47526568 0.47197467]
# selected action: 0
# action values: [0.50015104 0.5030743 ]
# selected action: 1
# action values: [0.47696146 0.47267723]
# selected action: 0
# action values: [0.5052174 0.5044072]
# selected action: 0
# action values: [0.48662147 0.4635125 ]
# selected action: 0
# action values: [0.48049146 0.4650317 ]
# selected action: 0
# action values: [0.48281184 0.4755283 ]
# selected action: 0
# action values: [0.49480367 0.49380615]
# selected action: 0
# action values: [0.50803244 0.5162437 ]
# selected action: 1
# action values: [0.4886273 0.4866605]
# selected action: 0
# action values: [0.5035548  0.51138586]
# selected action: 1
# action values: [0.48569813 0.48076013]
# selected action: 0
# action values: [0.5042698  0.50672364]
# selected action: 1
# action values: [0.48471016 0.477156  ]
# selected action: 0
# action values: [0.5071266 0.5038887]
# selected action: 0
# action values: [0.5253144 0.543795 ]
# selected action: 1
# action values: [0.5068805 0.5026915]
# selected action: 0
# action values: [0.53569144 0.54474354]
# selected action: 1
# action values: [0.48931876 0.488033  ]
# selected action: 0
# action values: [0.4842254  0.48457018]
# selected action: 1
# action values: [0.48860577 0.4866664 ]
# action values: [0.48473477 0.4843189 ]
# selected action: 0
# action values: [0.4890847 0.4883122]
# selected action: 0
# action values: [0.5049845 0.5040442]
# selected action: 0
# action values: [0.52160275 0.52712387]
# selected action: 1
# action values: [0.50453866 0.49937963]
# selected action: 0
# action values: [0.5226177 0.5248448]
# selected action: 1
# action values: [0.5046907 0.4982861]
# selected action: 0
# action values: [0.5242891 0.5234763]
# selected action: 0
# action values: [0.5569746  0.56160384]
# selected action: 1
# action values: [0.5252477 0.5099615]
# selected action: 0
# action values: [0.518493   0.51088685]
# selected action: 0
# action values: [0.521246   0.51530015]
# selected action: 0
# action values: [0.5327809 0.5287347]
# selected action: 0
# action values: [0.5428235  0.54371685]
# selected action: 1
# action values: [0.52572554 0.52387714]
# selected action: 0
# action values: [0.5403298 0.539338 ]
# selected action: 0
# action values: [0.5549603  0.57533884]
# selected action: 1
# action values: [0.537182  0.5354221]
# selected action: 0
# action values: [0.5539222  0.57033193]
# selected action: 1
# action values: [0.53609985 0.5338612 ]
# selected action: 0
# action values: [0.5450999 0.5339526]
# action values: [0.53484666 0.53121173]
# action values: [0.5351321 0.5340744]
# action values: [0.54478186 0.54291165]
# action values: [0.55568916 0.5561752 ]
# action values: [0.53814745 0.5385611 ]
# action values: [0.5255532 0.5271975]
# action values: [0.52042836 0.5276535 ]
# action values: [0.52526224 0.52879643]
# action values: [0.5444928 0.5512769]
# action values: [0.5587501 0.5722598]
# action values: [0.5869912 0.6037016]
# action values: [0.61362654 0.6415914 ]
# action values: [0.6509918 0.6844406]
# action values: [0.7003863  0.73043376]
# action values: [0.7520018  0.77492434]
# action values: [0.7983489  0.81767416]
# action values: [0.8492434  0.86281145]
# action values: [0.9157572  0.91492826]
# action values: [0.87341905 0.852247  ]
# action values: [0.5432964  0.53131044]
# selected action: 0
# action values: [0.53674513 0.5318551 ]
# selected action: 0
# action values: [0.5383244  0.53377557]
# selected action: 0
# action values: [0.55099726 0.5454701 ]
# selected action: 0
# action values: [0.5619539 0.5589893]
# selected action: 0
# action values: [0.5760511  0.59297985]
# selected action: 1
# action values: [0.5582964 0.5535679]
# selected action: 0
# action values: [0.5733953 0.586982 ]
# selected action: 1
# action values: [0.5551362  0.55071837]
# selected action: 0
# action values: [0.57529616 0.58129334]
# selected action: 1
# action values: [0.56108284 0.55366576]
# selected action: 0
# action values: [0.5511953  0.54873645]
# selected action: 0
# action values: [0.54633605 0.5491686 ]
# selected action: 1
# action values: [0.5475434 0.5470596]
# selected action: 0
# action values: [0.5438174 0.5470845]
# selected action: 1
# action values: [0.5442673 0.5452511]
# selected action: 1
# action values: [0.5527412 0.5515851]
# selected action: 0
# action values: [0.54382116 0.5446719 ]
# selected action: 1
# action values: [0.5493648  0.54933995]
# selected action: 0
# action values: [0.5433314 0.5441322]
# selected action: 1
# action values: [0.5443608 0.5472318]
# selected action: 1
# action values: [0.56900424 0.5718589 ]
# selected action: 1
# action values: [0.5871812  0.59471107]
# selected action: 1
# action values: [0.6164452 0.6291093]
# selected action: 1
# action values: [0.6427233 0.6676305]
# selected action: 1
# action values: [0.68118286 0.7062795 ]
# selected action: 1
# action values: [0.73134446 0.754473  ]
# selected action: 1
# action values: [0.7832844  0.79889613]
# selected action: 1
# action values: [0.83173513 0.84295565]
# selected action: 1
# action values: [0.88807905 0.88906604]
# selected action: 1
# action values: [0.95641947 0.94313353]
# selected action: 0
# action values: [0.581203  0.5754537]
# selected action: 0
# action values: [0.5673145  0.56602263]
# selected action: 0
# action values: [0.5623556  0.56413865]
# selected action: 1
# action values: [0.56432885 0.5643889 ]
# selected action: 1
# action values: [0.577262  0.5735313]
# selected action: 0
# action values: [0.56426865 0.5631996 ]
# selected action: 0
# action values: [0.5606854  0.56153977]
# selected action: 1
# action values: [0.56141245 0.56128776]
# selected action: 0
# action values: [0.55907285 0.5596125 ]
# selected action: 1
# action values: [0.55876106 0.5595132 ]
# selected action: 1
# action values: [0.56229514 0.5674531 ]
# selected action: 1
# action values: [0.58745533 0.5917585 ]
# selected action: 1
# action values: [0.6059698  0.61410874]
# selected action: 1
# action values: [0.6337955 0.6482674]
# selected action: 1
# action values: [0.6598732 0.6858219]
# selected action: 1
# action values: [0.6951024  0.72329444]
# selected action: 1
# action values: [0.74448377 0.76926416]
# selected action: 1
# action values: [0.7958857  0.81525624]
# selected action: 1
# action values: [0.84302783 0.856695  ]
# selected action: 1
# action values: [0.89196044 0.9006835 ]
# selected action: 1
# action values: [0.95688707 0.95142853]
# selected action: 0
# action values: [0.9144743 0.8910909]
# selected action: 0
# action values: [0.6152648 0.5985535]
# selected action: 0
# action values: [0.60120964 0.5938947 ]
# selected action: 0
# action values: [0.59267265 0.5936021 ]
# selected action: 1
# action values: [0.5974244 0.5927546]
# selected action: 0
# action values: [0.58865774 0.5914645 ]
# selected action: 1
# action values: [0.5934143  0.59135425]
# selected action: 0
# action values: [0.58582366 0.5892996 ]
# selected action: 1
# action values: [0.58994937 0.5899592 ]
# selected action: 1
# action values: [0.60752255 0.60193187]
# selected action: 0
# action values: [0.5895133 0.5893801]
# selected action: 0
# action values: [0.5830962  0.58658737]
# selected action: 1
# action values: [0.58655256 0.58800226]
# selected action: 1
# action values: [0.6045535 0.600936 ]
# selected action: 0
# action values: [0.58654356 0.58744794]
# selected action: 1
# action values: [0.6038419  0.59960204]
# selected action: 0
# action values: [0.5865118  0.58690774]
# selected action: 1
# action values: [0.60293233 0.598095  ]
# selected action: 0
# action values: [0.5864617  0.58638364]
# selected action: 0
# action values: [0.5812345  0.58281744]
# selected action: 1
# action values: [0.5837939  0.58483034]
# selected action: 1
# action values: [0.5986904  0.59460473]
# selected action: 0
# action values: [0.583922   0.58356094]
# selected action: 0
# action values: [0.57993644 0.58035797]
# selected action: 1
# action values: [0.5811738  0.58135617]
# selected action: 1
# action values: [0.58746225 0.58966726]
# selected action: 1
# action values: [0.6125918  0.61536443]
# selected action: 1
# action values: [0.6300685  0.63804716]
# selected action: 1
# action values: [0.65868354 0.6721027 ]
# selected action: 1
# action values: [0.6835584  0.70953816]
# selected action: 1
# action values: [0.71825665 0.7474352 ]
# selected action: 1
# action values: [0.76636314 0.7943533 ]
# selected action: 1
# action values: [0.8154487 0.8378449]
# selected action: 1
# action values: [0.86092097 0.87981975]
# selected action: 1
# action values: [0.91005975 0.92330515]
# selected action: 1
# action values: [0.97417814 0.97413826]
# selected action: 0
# action values: [0.93203557 0.91399866]
# selected action: 0
# action values: [0.6256418 0.6157576]
# selected action: 0
# action values: [0.61243063 0.6094999 ]
# selected action: 0
# action values: [0.6061522 0.6055625]
# selected action: 0
# action values: [0.6137885 0.6098942]
# selected action: 0
# action values: [0.62272435 0.6194397 ]
# selected action: 0
# action values: [0.63047385 0.6440754 ]
# selected action: 1
# action values: [0.6170532 0.613494 ]
# selected action: 0
# action values: [0.62608916 0.63739574]
# selected action: 1
# action values: [0.6119793 0.6075881]
# selected action: 0
# action values: [0.6565708  0.63730425]
# selected action: 0
# action values: [0.6423672 0.6321118]
# selected action: 0
# action values: [0.6304111 0.6292589]
# selected action: 0
# action values: [0.6261604 0.6343186]
# selected action: 1
# action values: [0.6247351  0.62554955]
# selected action: 1
# action values: [0.6317219 0.6282338]
# selected action: 0
# action values: [0.6219341  0.62340975]
# selected action: 1
# action values: [0.6283584 0.6268367]
# selected action: 0
# action values: [0.6195546 0.6213156]
# selected action: 1
# action values: [0.6255397  0.62566817]
# selected action: 1
# action values: [0.6438653 0.6393209]
# selected action: 0
# action values: [0.6254853 0.6249327]
# selected action: 0
# action values: [0.6174224  0.61851615]
# selected action: 1
# action values: [0.6229111 0.6232663]
# selected action: 1
# action values: [0.6405058 0.6369303]
# selected action: 0
# action values: [0.6228935 0.6216585]
# selected action: 0
# action values: [0.61592674 0.6157334 ]
# selected action: 0
# action values: [0.61934555 0.6172436 ]
# selected action: 0
# action values: [0.6246113 0.630156 ]
# selected action: 1
# action values: [0.6176131  0.61150265]
# selected action: 0
# action values: [0.62259537 0.62255096]
# selected action: 0
# action values: [0.62428945 0.6441341 ]
# selected action: 1
# action values: [0.61741644 0.61503035]
# selected action: 0
# action values: [0.6708064 0.6573762]
# selected action: 0
# action values: [0.6512772 0.6458927]
# selected action: 0
# action values: [0.6425583  0.64095986]
# selected action: 0
# action values: [0.6445975 0.6413504]
# selected action: 0
# action values: [0.6494429  0.64832884]
# selected action: 0
# action values: [0.65067375 0.66801935]
# selected action: 1
# action values: [0.6405142 0.640784 ]
# selected action: 1
# action values: [0.631575  0.6308234]
# selected action: 0
# action values: [0.63565475 0.63502383]
# selected action: 0
# action values: [0.6482047 0.6531254]
# selected action: 1
# action values: [0.6987872  0.67756325]
# action values: [0.6802609  0.67008877]
# action values: [0.66739804 0.6655277 ]
# action values: [0.6635166  0.66627383]
# action values: [0.6620537  0.66224104]
# action values: [0.6698749  0.66659606]
# action values: [0.65945023 0.66012263]
# action values: [0.6664775 0.6649133]
# action values: [0.65691525 0.6579942 ]
# action values: [0.6633659 0.6629048]
# action values: [0.6543874 0.6558352]
# action values: [0.6602351 0.66088  ]
# action values: [0.67392343 0.6745521 ]
# action values: [0.69588035 0.6977092 ]
# action values: [0.7079368  0.71519315]
# action values: [0.73067737 0.74309176]
# action values: [0.7439471 0.7670054]
# action values: [0.7669928  0.79235303]
# action values: [0.8049305 0.8280872]
# action values: [0.8389212 0.8531178]
# action values: [0.8721308  0.88177633]
# action values: [0.9094377 0.9108367]
# action values: [0.95889175 0.9451696 ]
# action values: [0.92664456 0.897458  ]
# action values: [0.70122486 0.6781869 ]
# selected action: 0
# action values: [0.68526727 0.6729975 ]
# selected action: 0
# action values: [0.6791822 0.6715656]
# selected action: 0
# action values: [0.6754028  0.67099255]
# selected action: 0
# action values: [0.6746553  0.67425364]
# selected action: 0
# action values: [0.67718726 0.6945124 ]
# selected action: 1
# action values: [0.666053  0.6666465]
# selected action: 1
# action values: [0.6544077 0.658398 ]
# selected action: 1
# action values: [0.65415996 0.6602114 ]
# selected action: 1
# action values: [0.655182 0.669108]
# selected action: 1
# action values: [0.67065895 0.6781055 ]
# selected action: 1
# action values: [0.6899491 0.6981173]
# selected action: 1
# action values: [0.6988663 0.7128974]
# selected action: 1
# action values: [0.7178689 0.7359074]
# selected action: 1
# action values: [0.73228997 0.7606805 ]
# selected action: 1
# action values: [0.75141805 0.79130554]
# selected action: 1
# action values: [0.7871919  0.82260096]
# selected action: 1
# action values: [0.8214513  0.85037833]
# selected action: 1
# action values: [0.8526461 0.8788756]
# selected action: 1
# action values: [0.8862128 0.908587 ]
# selected action: 1
# action values: [0.9260391 0.9381615]
# selected action: 1
# action values: [0.97949076 0.97441554]
# selected action: 0
# action values: [0.7066412  0.70243645]
# selected action: 0
# action values: [0.6870355  0.68737096]
# selected action: 1
# action values: [0.70578974 0.70099556]
# selected action: 0
# action values: [0.6867474 0.6861742]
# selected action: 0
# action values: [0.6792835  0.67857593]
# selected action: 0
# action values: [0.6783023  0.67542005]
# selected action: 0
# action values: [0.68178725 0.6810041 ]
# selected action: 0
# action values: [0.6826259 0.6949736]
# selected action: 1
# action values: [0.67496836 0.6711989 ]
# selected action: 0
# action values: [0.6739042 0.6865808]
# selected action: 1
# action values: [0.667412   0.66171783]
# selected action: 0
# action values: [0.73685014 0.720199  ]
# selected action: 0
# action values: [0.718984  0.7137076]
# selected action: 0
# action values: [0.710618  0.7096641]
# selected action: 0
# action values: [0.70766747 0.70737493]
# selected action: 0
# action values: [0.7092198 0.7122446]
# selected action: 1
# action values: [0.6993941 0.7022082]
# selected action: 1
# action values: [0.6968044 0.7022074]
# selected action: 1
# action values: [0.6996232  0.70817554]
# selected action: 1
# action values: [0.71188736 0.718061  ]
# selected action: 1
# action values: [0.7309693  0.73612726]
# selected action: 1
# action values: [0.73706985 0.7478816 ]
# selected action: 1
# action values: [0.7526264 0.7681659]
# selected action: 1
# action values: [0.75997496 0.7873628 ]
# selected action: 1
# action values: [0.77278364 0.8076302 ]
# selected action: 1
# action values: [0.80306506 0.8351856 ]
# selected action: 1
# action values: [0.83002365 0.8539177 ]
# selected action: 1
# action values: [0.85536563 0.8761816 ]
# selected action: 1
# action values: [0.88224256 0.89810264]
# selected action: 1
# action values: [0.91978705 0.923332  ]
# selected action: 1
# action values: [0.9674295 0.956094 ]
# selected action: 0
# action values: [0.7473057 0.7445456]
# selected action: 0
# action values: [0.7319744  0.73593736]
# selected action: 1
# action values: [0.7466943 0.7438241]
# selected action: 0
# action values: [0.73174936 0.73556185]
# selected action: 1
# action values: [0.74568653 0.7428776 ]
# selected action: 0
# action values: [0.73150045 0.7351694 ]
# selected action: 1
# action values: [0.74438214 0.7416495 ]
# selected action: 0
# action values: [0.7312221  0.73475814]
# selected action: 1
# action values: [0.7430741 0.7401942]
# selected action: 0
# action values: [0.73088163 0.7341955 ]
# selected action: 1
# action values: [0.7403015  0.73937774]
# selected action: 0
# action values: [0.7291449 0.7334677]
# selected action: 1
# action values: [0.73668665 0.7383801 ]
# selected action: 1
# action values: [0.75136566 0.754254  ]
# selected action: 1
# action values: [0.75374544 0.76139295]
# selected action: 1
# action values: [0.76440436 0.7756655 ]
# selected action: 1
# action values: [0.76978546 0.79305434]
# selected action: 1
# action values: [0.77842367 0.8123301 ]
# selected action: 1
# action values: [0.7985072  0.82873106]
# selected action: 1
# action values: [0.8203449 0.8422209]
# selected action: 1
# action values: [0.84084857 0.8611245 ]
# selected action: 1
# action values: [0.86799145 0.8789829 ]
# selected action: 1
# action values: [0.90106875 0.89992917]
# selected action: 0
# action values: [0.7694249 0.7584518]
# selected action: 0
# action values: [0.75288683 0.74792385]
# selected action: 0
# action values: [0.7448049  0.74181056]
# selected action: 0
# action values: [0.7420699  0.73586255]
# selected action: 0
# action values: [0.74303067 0.73796004]
# selected action: 0
# action values: [0.7402143 0.7509474]
# selected action: 1
# action values: [0.73209435 0.7282789 ]
# selected action: 0
# action values: [0.7314388 0.7398083]
# selected action: 1
# action values: [0.7232664  0.71797866]
# selected action: 0
# action values: [0.78814447 0.77780914]
# selected action: 0
# action values: [0.7771797 0.7757065]
# selected action: 0
# action values: [0.7708217 0.768828 ]
# selected action: 0
# action values: [0.7683266  0.76336336]
# selected action: 0
# action values: [0.76950306 0.76416326]
# selected action: 0
# action values: [0.76748127 0.78020495]
# selected action: 1
# action values: [0.7594484 0.7559794]
# selected action: 0
# action values: [0.7563465  0.76947945]
# selected action: 1
# action values: [0.74936    0.74588954]
# selected action: 0
# action values: [0.7511187  0.75749546]
# selected action: 1
# action values: [0.8147396  0.79948467]
# selected action: 0
# action values: [0.79723203 0.7915017 ]
# selected action: 0
# action values: [0.7859968  0.78423434]
# selected action: 0
# action values: [0.7793975 0.7764762]
# selected action: 0
# action values: [0.7748525 0.7748529]
# selected action: 1
# action values: [0.7710637  0.77106947]
# selected action: 1
# action values: [0.7721244 0.7759605]
# selected action: 1
# action values: [0.7767042  0.78515744]
# selected action: 1
# action values: [0.78549314 0.79588723]
# selected action: 1
# action values: [0.80305266 0.8091633 ]
# selected action: 1
# action values: [0.804036 0.815892]
# selected action: 1
# action values: [0.80311453 0.8238733 ]
# selected action: 1
# action values: [0.79851747 0.8319544 ]
# selected action: 1
# action values: [0.7936089 0.8397952]
# selected action: 1
# action values: [0.80163276 0.8489767 ]
# selected action: 1
# action values: [0.811633  0.8535396]
# selected action: 1
# action values: [0.8201313  0.85939926]
# selected action: 1
# action values: [0.8283889 0.8659091]
# selected action: 1
# action values: [0.83878005 0.872901  ]
# selected action: 1
# action values: [0.85618925 0.87966   ]
# selected action: 1
# action values: [0.8285317 0.8210193]
# action values: [0.8124266 0.8102764]
# action values: [0.7973752  0.79993284]
# action values: [0.8086747  0.80812347]
# action values: [0.7941443 0.7972613]
# action values: [0.80407083 0.8062404 ]
# action values: [0.8140601 0.8185408]
# action values: [0.8288589 0.8312702]
# action values: [0.82790196 0.83571047]
# action values: [0.8285456 0.8410822]
# action values: [0.82349205 0.8455873 ]
# action values: [0.8175284 0.8477931]
# action values: [0.82093155 0.84758294]
# action values: [0.82730544 0.8441439 ]
# action values: [0.8340111  0.84568375]
# action values: [0.8412216 0.8470628]
# action values: [0.8566916  0.84801817]
# action values: [0.8470689 0.8239335]
# action values: [0.8431898 0.8212283]
# selected action: 0
# action values: [0.826803   0.81774545]
# selected action: 0
# action values: [0.80946004 0.8084187 ]
# selected action: 0
# action values: [0.7964424 0.8039881]
# selected action: 1
# action values: [0.8047165 0.8052612]
# selected action: 1
# action values: [0.8174422 0.8167031]
# selected action: 0
# action values: [0.802184  0.8034501]
# selected action: 1
# action values: [0.81437397 0.81586796]
# selected action: 1
# action values: [0.8345554 0.8286601]
# selected action: 0
# action values: [0.8139696 0.8152199]
# selected action: 1
# action values: [0.83468246 0.82859963]
# selected action: 0
# action values: [0.813523  0.8145163]
# selected action: 1
# action values: [0.8347763  0.82848626]
# selected action: 0
# action values: [0.81302524 0.81375116]
# selected action: 1
# action values: [0.8348282  0.82831424]
# selected action: 0
# action values: [0.812466  0.8129165]
# selected action: 1
# action values: [0.8348292  0.82807624]
# selected action: 0
# action values: [0.81183356 0.81200325]
# selected action: 1
# action values: [0.8347689  0.82776356]
# selected action: 0
# action values: [0.81111455 0.8109999 ]
# selected action: 0
# action values: [0.79818475 0.7978257 ]
# selected action: 0
# action values: [0.78783387 0.78903735]
# selected action: 1
# action values: [0.7938165 0.7941151]
# selected action: 1
# action values: [0.80289006 0.80642265]
# selected action: 1
# action values: [0.8274975 0.826435 ]
# selected action: 0
# action values: [0.8026913  0.80415356]
# selected action: 1
# action values: [0.8246857 0.8246272]
# selected action: 0
# action values: [0.80148345 0.80231774]
# selected action: 1
# action values: [0.8201951 0.821522 ]
# selected action: 1
# action values: [0.8331432 0.8350741]
# selected action: 1
# action values: [0.8327757 0.840846 ]
# selected action: 1
# action values: [0.8360964 0.8509821]
# selected action: 1
# action values: [0.8278158 0.8531114]
# selected action: 1
# action values: [0.8277214 0.8545377]
# selected action: 1
# action values: [0.8342143 0.8574575]
# selected action: 1
# action values: [0.8416398  0.85346264]
# selected action: 1
# action values: [0.8481097 0.8553282]
# selected action: 1
# action values: [0.8552697 0.8566561]
# selected action: 1
# action values: [0.8719591  0.85966533]
# selected action: 0
# action values: [0.8454781  0.84455264]
# selected action: 0
# action values: [0.82851624 0.8327241 ]
# selected action: 1
# action values: [0.84526175 0.8431156 ]
# selected action: 0
# action values: [0.82814485 0.8310381 ]
# selected action: 1
# action values: [0.84350777 0.8409407 ]
# selected action: 0
# action values: [0.8276037 0.8292151]
# selected action: 1
# action values: [0.84077424 0.83963966]
# selected action: 0
# action values: [0.82602715 0.8275201 ]
# selected action: 1
# action values: [0.83659816 0.8388008 ]
# selected action: 1
# action values: [0.84762806 0.84853923]
# selected action: 1
# action values: [0.84338075 0.8496504 ]
# selected action: 1
# action values: [0.8395782 0.8495354]
# selected action: 1
# action values: [0.8323949  0.85087097]
# selected action: 1
# action values: [0.82235384 0.84915966]
# selected action: 1
# action values: [0.8179799  0.84148896]
# selected action: 1
# action values: [0.81823236 0.8324679 ]
# selected action: 1
# action values: [0.8192701 0.8285078]
# selected action: 1
# action values: [0.8219382  0.82497525]
# selected action: 1
# action values: [0.83136266 0.8210933 ]
# selected action: 0
# action values: [0.82605803 0.8007805 ]
# selected action: 0
# action values: [0.87046117 0.86270577]
# selected action: 0
# action values: [0.85172987 0.8510383 ]
# selected action: 0
# action values: [0.83876556 0.8399264 ]
# selected action: 1
# action values: [0.8471937 0.8495448]
# selected action: 1
# action values: [0.86139804 0.8601995 ]
# selected action: 0
# action values: [0.84530896 0.8479663 ]
# selected action: 1
# action values: [0.85582656 0.85771984]
# selected action: 1
# action values: [0.86919594 0.8683052 ]
# selected action: 0
# action values: [0.8521345  0.85481215]
# selected action: 1
# action values: [0.86949235 0.86628133]
# selected action: 0
# action values: [0.84813523 0.85191995]
# selected action: 1
# action values: [0.8688514 0.8640045]
# selected action: 0
# action values: [0.8445843 0.8499176]
# selected action: 1
# action values: [0.8668602 0.8612827]
# selected action: 0
# action values: [0.84412   0.8480135]
# selected action: 1
# action values: [0.86415946 0.85827833]
# selected action: 0
# action values: [0.84415954 0.8465356 ]
# selected action: 1
# action values: [0.8620864  0.85431695]
# selected action: 0
# action values: [0.84501344 0.84564483]
# selected action: 1
# action values: [0.85790455 0.84745824]
# selected action: 0
# action values: [0.84799063 0.8428801 ]
# selected action: 0
# action values: [0.84811866 0.83292705]
# selected action: 0
# action values: [0.8433248  0.80942154]
# selected action: 0
# action values: [0.85314536 0.793247  ]
# selected action: 0
# action values: [0.8560515 0.7918686]
# selected action: 0
# action values: [0.89625347 0.88307244]
# selected action: 0
# action values: [0.8783231 0.8721696]
# selected action: 0
# action values: [0.86138356 0.8628673 ]
# selected action: 1
# action values: [0.874911  0.8706279]
# selected action: 0
# action values: [0.8583312 0.8602873]
# selected action: 1
# action values: [0.8713665  0.86899656]
# selected action: 0
# action values: [0.85519034 0.8575175 ]
# selected action: 1
# action values: [0.867835  0.8668184]
# selected action: 0
# action values: [0.85155535 0.8545572 ]
# selected action: 1
# action values: [0.8629964  0.86471874]
# selected action: 1
# action values: [0.8737526 0.8800173]
# selected action: 1
# action values: [0.88660276 0.8902677 ]
# selected action: 1
# action values: [0.8822914 0.8905438]
# selected action: 1
# action values: [0.8722186 0.8872391]
# selected action: 1
# action values: [0.8572582  0.88143545]
# selected action: 1
# action values: [0.8397247 0.8723552]
# selected action: 1
# action values: [0.82684046 0.85953486]
# selected action: 1
# action values: [0.81866676 0.8427859 ]
# selected action: 1
# action values: [0.81109816 0.82970643]
# selected action: 1
# action values: [0.80297285 0.81764764]
# selected action: 1
# action values: [0.7994504 0.8048425]
# selected action: 1
# action values: [0.8038831  0.79624134]
# selected action: 0
# action values: [0.91223824 0.9071089 ]
# selected action: 0
# action values: [0.89181805 0.89306015]
# selected action: 1
# action values: [0.9117383 0.9059892]
# selected action: 0
# action values: [0.8911701  0.89084905]
# selected action: 0
# action values: [0.87723243 0.87573403]
# selected action: 0
# action values: [0.8638816 0.8615551]
# selected action: 0
# action values: [0.84861547 0.84771395]
# selected action: 0
# action values: [0.83766085 0.8521401 ]
# selected action: 1
# action values: [0.8369333 0.8342845]
# selected action: 0
# action values: [0.8242967 0.8376866]
# selected action: 1
# action values: [0.8250954  0.82024837]
# selected action: 0
# action values: [0.93168193 0.9280331 ]
# selected action: 0
# action values: [0.91410875 0.9182656 ]
# selected action: 1
# action values: [0.93059057 0.92727894]
# selected action: 0
# action values: [0.9129502 0.91625  ]
# selected action: 1
# action values: [0.92847174 0.9258871 ]
# selected action: 0
# action values: [0.91151166 0.9147669 ]
# selected action: 1
# action values: [0.9256527 0.9245068]
# selected action: 0
# action values: [0.9089133  0.91346043]
# selected action: 1
# action values: [0.9222672 0.9239305]
# selected action: 1
# action values: [0.9282251  0.93016773]
# selected action: 1
# action values: [0.9126221 0.9202885]
# selected action: 1
# action values: [0.8960696  0.90889895]
# selected action: 1
# action values: [0.8766776  0.89922905]
# selected action: 1
# action values: [0.8467825  0.87978846]
# selected action: 1
# action values: [0.8261389 0.8538096]
# selected action: 1
# action values: [0.80811983 0.82642055]
# selected action: 1
# action values: [0.7907907 0.8049936]
# selected action: 1
# action values: [0.77450097 0.7841022 ]
# selected action: 1
# action values: [0.7663109  0.76290417]
# selected action: 0
# ...
# selected action: 1
# action values: [3.481136  3.5086284]
# selected action: 1
# action values: [3.0800333 3.1148202]
# selected action: 1
# action values: [2.681071 2.722344]
# selected action: 1
# action values: [2.2907262 2.3371198]
# selected action: 1
# action values: [1.9156599 1.964742 ]
# selected action: 1
# action values: [1.5519437 1.6027915]
# selected action: 1
# action values: [1.2085543 1.2528048]
# selected action: 1
# action values: [0.8696562 0.9057844]
# selected action: 1
# action values: [0.5354532 0.5678348]
# selected action: 1
# action values: [0.2054161 0.2325295]
# selected action: 1
# action values: [4.5984077 4.57796  ]
# selected action: 0
# action values: [4.5017524 4.5259247]
# selected action: 1
# action values: [4.5635867 4.547016 ]
# selected action: 0
# action values: [4.4591136 4.4859266]
# selected action: 1
# action values: [4.5228415 4.511239 ]
# selected action: 0
# action values: [4.4090614 4.4391894]
# selected action: 1
# action values: [4.4755116 4.469511 ]
# selected action: 0
# action values: [4.343106  4.3771772]
# selected action: 1
# action values: [4.420806 4.421625]
# selected action: 1
# action values: [4.2979445 4.2820277]
# selected action: 0
# action values: [4.4077306 4.412201 ]
# selected action: 1
# action values: [4.307819  4.2891684]
# selected action: 0
# action values: [4.391673  4.3999286]
# selected action: 1
# action values: [4.3092933 4.288088 ]
# selected action: 0
# action values: [4.372166  4.3844433]
# selected action: 1
# action values: [4.303064  4.2807984]
# selected action: 0
# action values: [4.348061  4.3641515]
# selected action: 1
# action values: [4.292063  4.2688785]
# selected action: 0
# action values: [4.319258  4.3395705]
# selected action: 1
# action values: [4.275183 4.251914]
# selected action: 0
# action values: [4.2827606 4.3072453]
# selected action: 1
# action values: [4.2525053 4.2294846]
# selected action: 0
# action values: [4.23338  4.261878]
# selected action: 1
# action values: [4.222686  4.2006373]
# selected action: 0
# action values: [4.1753926 4.208508 ]
# selected action: 1
# action values: [4.178477  4.1612988]
# selected action: 0
# action values: [4.1059566 4.144661 ]
# selected action: 1
# action values: [4.1239314 4.113484 ]
# selected action: 0
# action values: [4.01351  4.055629]
# selected action: 1
# action values: [4.0551963 4.0519547]
# selected action: 0
# action values: [3.8899941 3.9328399]
# selected action: 1
# action values: [3.9666    3.9706342]
# selected action: 1
# action values: [3.8647144 3.8525825]
# selected action: 0
# action values: [3.9149756 3.924106 ]
# selected action: 1
# action values: [3.84576   3.8317473]
# selected action: 0
# action values: [3.8492074 3.8658597]
# selected action: 1
# action values: [3.799301  3.7845666]
# selected action: 0
# action values: [3.7611616 3.7852788]
# selected action: 1
# action values: [3.7344613 3.7191427]
# selected action: 0
# action values: [3.6375968 3.666836 ]
# selected action: 1
# action values: [3.6436677 3.6340892]
# selected action: 0
# action values: [3.4815333 3.5157394]
# selected action: 1
# action values: [3.53273   3.5307043]
# selected action: 0
# action values: [3.2917647 3.3329568]
# selected action: 1
# action values: [3.3817756 3.3834743]
# selected action: 1
# action values: [3.3181472 3.3028252]
# selected action: 0
# action values: [3.236356 3.237825]
# selected action: 1
# action values: [3.2322047 3.2122953]
# selected action: 0
# action values: [3.0558667 3.0590746]
# selected action: 1
# action values: [3.0899944 3.0677998]
# selected action: 0
# action values: [2.8457465 2.8544533]
# selected action: 1
# action values: [4.814145  4.7744455]
# selected action: 0
# action values: [4.7692533 4.768766 ]
# selected action: 0
# action values: [4.528069  4.5393424]
# selected action: 1
# action values: [4.710086  4.7136774]
# selected action: 1
# action values: [4.747609  4.7099032]
# selected action: 0
# action values: [4.694136 4.698931]
# selected action: 1
# action values: [4.732468  4.6954594]
# selected action: 0
# action values: [4.676261  4.6821427]
# selected action: 1
# action values: [4.7157063 4.6796565]
# selected action: 0
# action values: [4.6561537 4.6630335]
# selected action: 1
# action values: [4.697086  4.6623178]
# selected action: 0
# action values: [4.633046  4.6414194]
# selected action: 1
# action values: [4.676629 4.643415]
# selected action: 0
# action values: [4.606552  4.6166377]
# selected action: 1
# action values: [4.65411   4.6226153]
# selected action: 0
# action values: [4.575564  4.5876055]
# selected action: 1
# action values: [4.6278186 4.598546 ]
# selected action: 0
# action values: [4.5402937 4.5544724]
# selected action: 1
# action values: [4.596668  4.5704403]
# selected action: 0
# action values: [4.5000405 4.5165854]
# selected action: 1
# action values: [4.5594506 4.5371895]
# selected action: 0
# action values: [4.453714  4.4729767]
# selected action: 1
# action values: [4.5154576 4.4985166]
# selected action: 0
# action values: [4.3987   4.421642]
# selected action: 1
# action values: [4.464319  4.4534507]
# selected action: 0
# action values: [4.3209314 4.3481026]
# selected action: 1
# action values: [4.404792 4.401487]
# selected action: 0
# action values: [4.2150683 4.242664 ]
# selected action: 1
# action values: [4.3357596 4.341249 ]
# selected action: 1
# action values: [4.253825  4.2311506]
# selected action: 0
# action values: [4.306693 4.317772]
# selected action: 1
# action values: [4.244708  4.2201543]
# selected action: 0
# action values: [4.2707286 4.2868466]
# selected action: 1
# action values: [4.2263865 4.2009616]
# selected action: 0
# action values: [4.218514  4.2388277]
# selected action: 1
# action values: [4.2000017 4.1743593]
# selected action: 0
# action values: [4.1574206 4.182524 ]
# selected action: 1
# action values: [4.1579075 4.1360273]
# selected action: 0
# action values: [4.0832653 4.1149855]
# selected action: 1
# action values: [4.1019597 4.0869555]
# selected action: 0
# action values: [3.9874222 4.023452 ]
# selected action: 1
# action values: [4.0279865 4.019877 ]
# selected action: 0
# action values: [3.8577845 3.8925018]
# selected action: 1
# action values: [3.9346519 3.934013 ]
# selected action: 0
# action values: [3.6946144 3.72801  ]
# selected action: 1
# action values: [3.823402  3.8307867]
# selected action: 1
# action values: [3.770333  3.7516203]
# selected action: 0
# action values: [3.737606  3.7539277]
# selected action: 1
# action values: [3.707614  3.6876261]
# selected action: 0
# action values: [3.6226137 3.6439009]
# selected action: 1
# action values: [3.6215682 3.6056879]
# selected action: 0
# action values: [3.47056   3.4970167]
# selected action: 1
# action values: [3.511292  3.5038228]
# selected action: 0
# action values: [3.2820623 3.311915 ]
# selected action: 1
# action values: [3.3620422 3.3602934]
# selected action: 0
# action values: [3.0509496 3.0825393]
# selected action: 1
# action values: [3.1590788 3.1585255]
# selected action: 0
# action values: [2.7776477 2.801304 ]
# selected action: 1
# action values: [2.9070833 2.9096327]
# selected action: 1
# action values: [4.64308  4.622387]
# selected action: 0
# action values: [4.5504994 4.57163  ]
# selected action: 1
# action values: [4.6062107 4.589257 ]
# selected action: 0
# action values: [4.4966035 4.5205445]
# selected action: 1
# action values: [4.5593405 4.54703  ]
# selected action: 0
# action values: [4.4301167 4.459163 ]
# selected action: 1
# action values: [4.4998093 4.4949684]
# selected action: 0
# action values: [4.344599  4.3785696]
# selected action: 1
# action values: [4.431096  4.4353495]
# selected action: 1
# action values: [4.334947 4.317628]
# selected action: 0
# action values: [4.4030676 4.413236 ]
# selected action: 1
# action values: [4.331854  4.3112497]
# selected action: 0
# action values: [4.3691545 4.3848004]
# selected action: 1
# action values: [4.320013  4.2977724]
# selected action: 0
# action values: [4.327667  4.3485603]
# selected action: 1
# action values: [4.2965074 4.2741666]
# selected action: 0
# action values: [4.274779  4.3012395]
# selected action: 1
# action values: [4.2660108 4.2437205]
# selected action: 0
# action values: [4.206704  4.2382646]
# selected action: 1
# action values: [4.216377 4.19944 ]
# selected action: 0
# action values: [4.122502 4.161293]
# selected action: 1
# action values: [4.154041 4.144745]
# selected action: 0
# action values: [4.0101633 4.04869  ]
# selected action: 1
# action values: [4.0733852 4.072195 ]
# selected action: 0
# action values: [3.8621607 3.900988 ]
# selected action: 1
# action values: [3.9690802 3.9758844]
# selected action: 1
# action values: [3.894009 3.878785]
# selected action: 0
# action values: [3.899244  3.9132962]
# selected action: 1
# action values: [3.8552582 3.838666 ]
# selected action: 0
# action values: [3.8052824 3.8290799]
# selected action: 1
# action values: [3.7879004 3.7704065]
# selected action: 0
# action values: [3.678787 3.708531]
# selected action: 1
# action values: [3.6910172 3.6811285]
# selected action: 0
# action values: [3.5164669 3.5500243]
# selected action: 1
# action values: [3.5732255 3.5716698]
# selected action: 0
# action values: [3.3181543 3.357021 ]
# selected action: 1
# action values: [3.4137518 3.4173338]
# selected action: 1
# action values: [3.3612502 3.3482015]
# selected action: 0
# action values: [3.2605178 3.2653089]
# selected action: 1
# action values: [3.26762  3.250945]
# selected action: 0
# action values: [3.0744956 3.0806775]
# selected action: 1
# action values: [3.1137254 3.0969753]
# selected action: 0
# action values: [2.850246  2.8632164]
# selected action: 1
# action values: [4.8361897 4.780616 ]
# selected action: 0
# action values: [4.828576 4.817726]
# selected action: 0
# action values: [4.6507277 4.655205 ]
# selected action: 1
# action values: [4.792468 4.78421 ]
# selected action: 0
# action values: [4.6106024 4.616643 ]
# selected action: 1
# action values: [4.7518177 4.746537 ]
# selected action: 0
# action values: [4.560136  4.5670805]
# selected action: 1
# action values: [4.7057776 4.7041006]
# selected action: 0
# action values: [4.493167  4.5012197]
# selected action: 1
# action values: [4.653038 4.655714]
# selected action: 1
# action values: [4.656473  4.6153746]
# selected action: 0
# action values: [4.6451864 4.648535 ]
# selected action: 1
# action values: [4.653069 4.611781]
# selected action: 0
# action values: [4.6364775 4.640585 ]
# selected action: 1
# action values: [4.649162  4.6077337]
# selected action: 0
# action values: [4.626766 4.631736]
# selected action: 1
# action values: [4.6439314 4.602684 ]
# selected action: 0
# action values: [4.615888  4.6218405]
# selected action: 1
# action values: [4.637822  4.5967207]
# selected action: 0
# action values: [4.6036487 4.6107244]
# selected action: 1
# action values: [4.6302075 4.5893583]
# selected action: 0
# action values: [4.5898232 4.5981865]
# selected action: 1
# action values: [4.6210217 4.5805187]
# selected action: 0
# action values: [4.5741177 4.5839653]
# selected action: 1
# action values: [4.609453 4.569726]
# selected action: 0
# action values: [4.555733 4.567376]
# selected action: 1
# action values: [4.5958343 4.556985 ]
# selected action: 0
# action values: [4.534849  4.5481663]
# selected action: 1
# action values: [4.580258  4.5424147]
# selected action: 0
# action values: [4.5110216 4.5260096]
# selected action: 1
# action values: [4.5614586 4.5251074]
# selected action: 0
# action values: [4.483628 4.50041 ]
# selected action: 1
# action values: [4.536284  4.5028286]
# selected action: 0
# action values: [4.4520397 4.470684 ]
# selected action: 1
# action values: [4.506898  4.4767923]
# selected action: 0
# action values: [4.4102926 4.430249 ]
# selected action: 1
# action values: [4.4729238 4.446783 ]
# selected action: 0
# action values: [4.360904  4.3821907]
# selected action: 1
# action values: [4.4334645 4.412281 ]
# selected action: 0
# action values: [4.3023777 4.3242884]
# selected action: 1
# action values: [4.3878574 4.372405 ]
# selected action: 0
# action values: [4.229385 4.252181]
# selected action: 1
# action values: [4.335089 4.32627 ]
# selected action: 0
# action values: [4.1342616 4.1566586]
# selected action: 1
# action values: [4.2710123 4.2695417]
# selected action: 0
# action values: [4.01483  4.034354]
# selected action: 1
# action values: [4.187908  4.1938906]
# selected action: 1
# action values: [4.148648  4.1182947]
# selected action: 0
# action values: [4.145493  4.1553707]
# selected action: 1
# action values: [4.130779 4.09926 ]
# selected action: 0
# action values: [4.0928144 4.1081305]
# selected action: 1
# action values: [4.097388  4.0682592]
# selected action: 0
# action values: [4.030372 4.051076]
# selected action: 1
# action values: [4.0426774 4.018158 ]
# selected action: 0
# action values: [3.9519    3.9803052]
# selected action: 1
# action values: [3.973044  3.9542992]
# selected action: 0
# action values: [3.8394084 3.8698862]
# selected action: 1
# action values: [3.8899217 3.8780446]
# selected action: 0
# action values: [3.697709  3.7289796]
# selected action: 1
# action values: [3.7918584 3.7880266]
# selected action: 0
# action values: [3.5296266 3.557803 ]
# selected action: 1
# action values: [3.6752083 3.6805677]
# selected action: 1
# action values: [3.6418917 3.614801 ]
# selected action: 0
# action values: [3.58241   3.5925815]
# selected action: 1
# action values: [3.5687878 3.5432136]
# selected action: 0
# action values: [3.44863   3.4640114]
# selected action: 1
# action values: [3.4704683 3.4516964]
# selected action: 0
# action values: [3.2818239 3.3005297]
# selected action: 1
# action values: [3.3474143 3.337528 ]
# selected action: 0
# action values: [3.0806038 3.1016128]
# selected action: 1
# action values: [3.1787179 3.1727011]
# selected action: 0
# action values: [2.8296056 2.8537955]
# selected action: 1
# action values: [2.9492223 2.943268 ]
# selected action: 0
# action values: [2.5402167 2.5548396]
# selected action: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_4/m5twwlnn26b0q41jgwd5jnz80000gq/T/ipykernel_26473/3832242952.py in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# /var/folders/_4/m5twwlnn26b0q41jgwd5jnz80000gq/T/ipykernel_26473/2054603240.py in main()
#      46             for i in range(0, 50):
#      47                 states_mb, acts_mb, rews_mb, next_states_mb, terminated = replay_buffer.sample_buffer(batch_size=32)
# ---> 48                 q_learning_agent.train(states_mb, acts_mb, rews_mb, next_states_mb, terminated)
#      49
#      50         if ep % 7 == 0 and ep > 0:
#
# /var/folders/_4/m5twwlnn26b0q41jgwd5jnz80000gq/T/ipykernel_26473/3866595737.py in train(self, states, acts, rews, next_states, terminated)
#      31
#      32         q_values = self.q_func(states_torch)# use your neural net
# ---> 33         next_q_values = self.q_func(next_states_torch)# use your neural net again
#      34
#      35         # This is the Q-values at the actions that were actually taken. So you need to fill in the second index to account for the actions that were taken.
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# /var/folders/_4/m5twwlnn26b0q41jgwd5jnz80000gq/T/ipykernel_26473/1534257243.py in forward(self, x)
#      10         out = self.fc1(x)
#      11         out = self.relu(out)
# ---> 12         out = self.fc2(out)
#      13         return out
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# # Please answer the following questions

# %% [markdown]
# # #1 Fill in the missing code.
# After finishing the code, plot the learning curve, with the x-axis being the number of training steps, and the y-axis being the amount of time cartpole survives. Note that this code will automatically be generated by lines 74-76 above, you don't have to write any additional code to do this.
#
# As we saw in class, the return can be quite unstable. Please include this plot in your final write-up.

# %% [markdown]
# # #2 Can you do better?
#
# Spend 10-30 minutes playing around with the algorithm. You might want to change the discount factor gamma. You can also change the number of times you train per episode collected, which is currently set to 20. Another interesting value is the rate at which the epsilon threshold in epsilon greedy exploration decays. You could also try changing the number of hidden units in the neural network. Or the optimizer learning rate.
#
# Please include your best learning curve in the final write-up. More importantly, what parameters were most important to training? Are there any parameters that negatively impact the results if they are changed?
